# %% [markdown]
# <a href="https://colab.research.google.com/github/dalcimar/SI27CP---Sistemas-Inteligentes/blob/main/L03_error_surface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 60
X1 = np.arange(-2, 2, 0.025)
X2 = np.arange(-2, 2, 0.025)
X1, X2 = np.meshgrid(X1, X2)

# %%
Z = 1*X1 + 0.5*X2 - 1

# %%
# Create a surface plot and projected filled contour plot under it.
fig = plt.figure(figsize=(20,7))

# Figure 1
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.plot_surface(X1, X2, Z, cmap='viridis')
ax.contourf(X1, X2, Z, zdir='z', offset=-4.15, cmap='viridis')

# Adjust the limits, ticks and view angle
#ax.set_zlim(-0,2)

plt.show()

# %%
fig = plt.figure(figsize=(20,7))

# Figure 2
ax = fig.add_subplot(1, 1, 1, projection='3d')
ax.contourf(X1, X2, Z, zdir='z', offset=-0.15, cmap='viridis')

plt.show()
